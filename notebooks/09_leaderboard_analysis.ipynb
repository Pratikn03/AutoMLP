# %% [markdown]
# # Notebook 09 — Leaderboard & Runtime Analysis

# %%
import pandas as pd
summary = pd.read_csv('reports/framework_summary.csv') if Path('reports/framework_summary.csv').exists() else pd.DataFrame()
summary.head()

# %% [markdown]
# Visuals can be embedded by loading the generated PNGs or re-running plot functions.
