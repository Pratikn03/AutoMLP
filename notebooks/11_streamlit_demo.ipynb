# %% [markdown]
# # Notebook 11 — Streamlit Demo

# %% [markdown]
# Document how to launch `streamlit run Project/streamlit_leaderboard.py` and include screenshots or sample outputs.

# %%
from IPython.display import Markdown; Markdown('Run `streamlit run Project/streamlit_leaderboard.py` in a terminal.')
