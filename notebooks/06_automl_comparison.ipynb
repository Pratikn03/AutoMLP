# %% [markdown]
# # Notebook 06 — AutoML Framework Comparison

# %%
import pandas as pd
from pathlib import Path
leaderboard_path = Path('reports/leaderboard_multi.csv')
if leaderboard_path.exists():
    leaderboard = pd.read_csv(leaderboard_path)
else:
    leaderboard = pd.DataFrame()
leaderboard.head()

# %% [markdown]
# ## Plot accuracy vs runtime using existing figure

# %%
from IPython.display import Image; Image('figures/pareto_accuracy_runtime.png')
