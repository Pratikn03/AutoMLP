# %% [markdown]
# # Notebook 03 — Deployment & Operations
#
# Connects packaging, CLI, FastAPI, and Make targets for the ops story.

# %% [markdown]
# ## 1. Package install / CLI
# ```
# pip install .
# automl-run --max-datasets 1
# ```
# The commands above exercise the same orchestrator defined in `scripts/run_all.py`.

# %% [markdown]
# ## 2. Inspect FastAPI app

# %%
from Deploy.api.serve.app import app
[route.path for route in app.routes][:10]

# %% [markdown]
# ## 3. Monitoring hooks
# - `make serve` → local uvicorn with Prometheus `/metrics`.
# - `make demo` → build & run Docker container.
# - `reports/runtime.json` → wall-clock + resource logs for each script.
