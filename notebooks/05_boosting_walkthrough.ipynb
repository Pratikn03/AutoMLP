# %% [markdown]
# # Notebook 05 — Boosting Walkthrough
#
# Run the gradient boosting baselines (XGBoost, LightGBM, CatBoost) on a single dataset and inspect their fold-level metrics.

# %% [markdown]
# ## 1. Imports & config

# %%
import pandas as pd
from pathlib import Path
from Project.trainers import train_boosters

DATA_PATH = Path('Project/src/data/modeldata_demo.csv')
TARGET_OVERRIDE = None  # set to column name if needed

# %% [markdown]
# ## 2. Launch booster training
# This mirrors `python Project/trainers/train_boosters.py` but can be run inline.

# %%
# Uncomment to run (can take several minutes depending on dataset)
# %run Project/trainers/train_boosters.py --data-path {DATA_PATH} --target {TARGET_OVERRIDE or ''}

# %% [markdown]
# ## 3. Inspect metrics

# %%
metrics_path = Path('reports/metrics')
for csv in metrics_path.glob('*_folds.csv'):
    print(csv)
    display(pd.read_csv(csv).head())

# %% [markdown]
# Document insights or copy plots from `figures/` here.
