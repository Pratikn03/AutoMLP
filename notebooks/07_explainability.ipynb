# %% [markdown]
# # Notebook 07 — Explainability

# %% [markdown]
# Load SHAP/LIME outputs produced by `Project/analysis/explain_shap.py`.

# %%
import pandas as pd
from pathlib import Path
shap_global = Path('reports/shap_global_summary.csv')
if shap_global.exists():
    display(pd.read_csv(shap_global).head())
else:
    print('Run Project/analysis/explain_shap.py first')

# %% [markdown]
# Include sample plots or describe insights here.
