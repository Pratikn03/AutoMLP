# %% [markdown]
# # Notebook 02 — Modelling & Metrics
#
# Loads the per-framework results emitted by the orchestrator and re-runs plotting utilities.

# %%
import pandas as pd
from pathlib import Path
leaderboard_path = Path('reports/leaderboard_multi.csv')
if leaderboard_path.exists():
    leaderboard = pd.read_csv(leaderboard_path)
else:
    leaderboard = pd.DataFrame()
leaderboard.head()

# %% [markdown]
# ## Refresh plots
# Run the same plotting code used by `make reproduce`.

# %%
from Project.analysis import plot_comparisons
plot_comparisons.main()
print("Updated figures under figures/ (including classifier_accuracy_precision.png)")
