# %% [markdown]
# # Notebook 08 — Calibration & Fairness

# %% [markdown]
# Document reliability curves / fairness metrics saved by analysis scripts.

# %%
import pandas as pd
fairness_path = Path('reports/slice_report_summary.json')
if fairness_path.exists():
    import json
    display(json.loads(fairness_path.read_text()))
else:
    print('Generate slice reports via Project/analysis/slice_report.py')
