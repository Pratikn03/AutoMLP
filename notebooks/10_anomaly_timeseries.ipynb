# %% [markdown]
# # Notebook 10 — Anomaly Detection & Timeseries

# %% [markdown]
# Explain how `Project/anomaly/tabular_anomaly.py` and `Project/timeseries/forecast_baseline.py` were executed; load their outputs.

# %%
from pathlib import Path
import json
anomaly = Path('reports/top_anomalies.csv')
if anomaly.exists():
    import pandas as pd
    display(pd.read_csv(anomaly).head())
else:
    print('Run Project/anomaly/tabular_anomaly.py to populate top_anomalies.csv')
